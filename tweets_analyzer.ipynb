# %% [markdown]
# <a href="https://colab.research.google.com/github/joicecg/tweets-analyzer/blob/master/tweets_analyzer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy
import re
import io

# %%
consumer_key = 'kUYa1d1gSdJGF1aJ6fmWyQUjl'
consumer_secret = 'qEdz3aIE5yKCJ82s7w0owGYu0MuerxNNj474Tn1F6U6EYt88uc'

access_token ='799084783-RyyIwVbBUnarbkCRLoVNrseBrfeeD8rzAkq11mXs'
access_token_secret = 'AQybtYKq9ABczEu3FfBwiM0K6frqaf5p7kdvNJl36TYSH'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
user = api.get_user('jairbolsonaro')
target = io.open("bolsonaro.txt", 'w', encoding='utf-8')

n = 0
for tweet in tweepy.Cursor(api.user_timeline,id='jairbolsonaro').items(10000):
    if tweet.text[:2] != 'RT' and "http" not in tweet.text: 
      n = n + 1
      target.write(str(n)+tweet.text+"\n")
      print(tweet.text)
# Out:
# @monark NÃO! 👍🏼
# @SF_Moro 👍🏼🇧🇷Vamos, Moro!
# @PHCRF1895 👍⚽️
# @oliverdieg 👍🇧🇷
# - Cumprimento os ministros @ernestofaraujo, Paulo Guedes e @TerezaCrisMS, que estiveram à frente das negociações. Grande dia!
# Como chefe de uma das maiores democracias do mundo, desejo ao povo francês paz e felicidades!
# @jiaoguilherme 👍
# @DadsDaughter777 👍
# - Em 1991 Norambuena foi condenado no Chile pelo assassinato do Senador Jaime Guzmán. - @SF_Moro
# - Provérbios 28:19: "Quem lavra sua terra terá comida com fartura, quem persegue fantasias se fartará de miséria."
# - O Rio Grande do Sul corre o risco, pela volta da esquerda na Argentina, de passar pelo mesmo sofrimento de Roraima em relação à Venezuela.
# - Os preços começam a se aproximar dos valores de um país cada vez mais semelhante à Venezuela.
# @Hum129 Um abraço fãs de Counter Strike! 👍
# Grande dia! 👍
# - Boa noite e um bom início de semana a todos! 🇧🇷
# ...

# %%
# empty list to store parsed tweets
tweets = []
target = io.open("mytweets.txt", 'w', encoding='utf-8')

# call twitter api to fetch tweets
a=str("bolsonaro")

#b=str(q+" sarcastic")
#c=str(q+" irony")

fetched_tweets = api.search(a, tweet_mode="extended", since_id=20190101, count = 1000)

n = 0
for tweet in fetched_tweets:
    if "http" not in tweet.full_text:
      n = n + 1
      if tweet.full_text[:2] == 'RT':
         print(str(n) + " " + tweet.retweeted_status.full_text)
        
      else:
        parsed_tweet = {}
        print(str(n) + " " + tweet.full_text)

        parsed_tweet['extended_tweet'] = tweet.full_text

        target.write(tweet.full_text+"\n")
# Out:
# 1 Os petistas, pelegos do PSOL e da UNE, os “pão com mortadela”, toda essa turma está na Universidade Federal do Ceará impedindo o reitor, escolhido legitimamente pelo presidente Jair Bolsonaro, de trabalhar. Só fazem arruaça e ainda chamam de ocupação. É muita vagabundagem mesmo.
# 2 É o seguinte:
# - O Nhonho quer destruir o Bolsonaro, só que para fazer isso ele precisa retirar o apoio popular do Jair e como fará isso? Através da liderança do PSL orientando votos errados.
#
# Qual a solução para evitar? Retirar imediatamente o Delegado Waldir da liderança.
# 3 Bolsonaro diz que vai saltar de paraquedas e convida ministro para ir junto. Vamos torcer gente, ... pra que tudo dê certo. 😂😂😂😂😂 @UOLNoticias @UOL https://t.co/jgWQleF0zB
# 4 Depois das últimas Fake News:
#
# Amazônia continua sendo do Brasil.
#
# Moro continua Ministro da Justiça.
#
# Bolsonaro continua presidente.
#
# Lula continua preso, babaca!
# ...
